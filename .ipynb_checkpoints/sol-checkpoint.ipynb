# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 1	Write a code to import  Dataframe in Python
df = pd.read_excel('Python Data.xlsx')

# %%
df
# Out:
#     Emp ID Region                  Name                    Department Month  \
# 0    10001   East          DeRusha, Joe  5255-Data/Connectivity Sales   Jan
# 1    10002   East  De Pasquale, Richard      5256-Sales Mgt & Support   Jan
# 2    10003   East        Dobbert, Susan               5257-Auto Sales   Jan
# 3    10001   East          DeRusha, Joe  5255-Data/Connectivity Sales   Jan
# 4    10002   East  De Pasquale, Richard      5256-Sales Mgt & Support   Jan
# 5    10003   East        Dobbert, Susan               5257-Auto Sales   Jan
# 6    10005   West         Dunton, Donna            5259-Sales Channel   Jan
# 7    10007   West      De Sousa, Kristi            5263-Sales Support   Jan
# 8    10004   East        Dillard, Susan                5258-IAP Sales   Jan
# 9    10005   West         Dunton, Donna            5259-Sales Channel   Jan
# 10   10006   West        De Vries, John                  5262-Auto GM   Jan
# 11   10007   West      De Sousa, Kristi            5263-Sales Support   Jan
# 12   10008   West       Defonso, Daniel                5264-ARD Sales   Jan
#
#     Year   Sales  Discounts                 Date     %Sales  % Discount  \
# 0   FY13  100000      25000           24-01-2023   2.985075   25.000000
# 1   FY13  150000      30000  2023-01-01 00:00:00   4.477612   20.000000
# 2   FY13  200000      35000  2023-01-08 00:00:00   5.970149   17.500000
# 3   FY13  100000      25000  2023-01-28 00:00:00   2.985075   25.000000
# 4   FY13  150000      30000  2023-01-21 00:00:00   4.477612   20.000000
# 5   FY13  200000      35000  2023-01-23 00:00:00   5.970149   17.500000
# 6   FY13  300000      45000  2023-01-14 00:00:00   8.955224   15.000000
# 7   FY13  400000      55000           28-01-2023  11.940299   13.750000
# 8   FY13  250000      40000  2023-01-28 00:00:00   7.462687   16.000000
# 9   FY13  300000      45000  2023-01-21 00:00:00   8.955224   15.000000
# 10  FY13  350000      50000  2023-01-23 00:00:00  10.447761   14.285714
# 11  FY13  400000      55000  2023-01-14 00:00:00  11.940299   13.750000
# 12  FY13  450000      60000           28-01-2023  13.432836   13.333333
#
#     Total Sales
# 0     3350000.0
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN

# %%
unique_names = df['Name'].unique()

# %%
unique_names
# Out:
# array(['DeRusha, Joe', 'De Pasquale, Richard', 'Dobbert, Susan',
#        'Dunton, Donna', 'De Sousa, Kristi', 'Dillard, Susan',
#        'De Vries, John', 'Defonso, Daniel'], dtype=object)

# %%
# 3	Write the code to find top 3 sales with Name and Department

top_3_sales = df.nlargest(3, 'Sales')[['Sales', 'Name', 'Department']]

# %%
# 4	Replace "DeRusha, Joe" Name with "John" in D Column

df['Name'] = df['Name'].replace('DeRusha, Joe', 'John')df['Name']

# %%
df['Name']
# Out:
# 0                     John
# 1     De Pasquale, Richard
# 2           Dobbert, Susan
# 3                     John
# 4     De Pasquale, Richard
# 5           Dobbert, Susan
# 6            Dunton, Donna
# 7         De Sousa, Kristi
# 8           Dillard, Susan
# 9            Dunton, Donna
# 10          De Vries, John
# 11        De Sousa, Kristi
# 12         Defonso, Daniel
# Name: Name, dtype: object

# %%
df
# Out:
#     Emp ID Region                  Name                    Department Month  \
# 0    10001   East                  John  5255-Data/Connectivity Sales   Jan
# 1    10002   East  De Pasquale, Richard      5256-Sales Mgt & Support   Jan
# 2    10003   East        Dobbert, Susan               5257-Auto Sales   Jan
# 3    10001   East                  John  5255-Data/Connectivity Sales   Jan
# 4    10002   East  De Pasquale, Richard      5256-Sales Mgt & Support   Jan
# 5    10003   East        Dobbert, Susan               5257-Auto Sales   Jan
# 6    10005   West         Dunton, Donna            5259-Sales Channel   Jan
# 7    10007   West      De Sousa, Kristi            5263-Sales Support   Jan
# 8    10004   East        Dillard, Susan                5258-IAP Sales   Jan
# 9    10005   West         Dunton, Donna            5259-Sales Channel   Jan
# 10   10006   West        De Vries, John                  5262-Auto GM   Jan
# 11   10007   West      De Sousa, Kristi            5263-Sales Support   Jan
# 12   10008   West       Defonso, Daniel                5264-ARD Sales   Jan
#
#     Year   Sales  Discounts                 Date     %Sales  % Discount  \
# 0   FY13  100000      25000           24-01-2023   2.985075   25.000000
# 1   FY13  150000      30000  2023-01-01 00:00:00   4.477612   20.000000
# 2   FY13  200000      35000  2023-01-08 00:00:00   5.970149   17.500000
# 3   FY13  100000      25000  2023-01-28 00:00:00   2.985075   25.000000
# 4   FY13  150000      30000  2023-01-21 00:00:00   4.477612   20.000000
# 5   FY13  200000      35000  2023-01-23 00:00:00   5.970149   17.500000
# 6   FY13  300000      45000  2023-01-14 00:00:00   8.955224   15.000000
# 7   FY13  400000      55000           28-01-2023  11.940299   13.750000
# 8   FY13  250000      40000  2023-01-28 00:00:00   7.462687   16.000000
# 9   FY13  300000      45000  2023-01-21 00:00:00   8.955224   15.000000
# 10  FY13  350000      50000  2023-01-23 00:00:00  10.447761   14.285714
# 11  FY13  400000      55000  2023-01-14 00:00:00  11.940299   13.750000
# 12  FY13  450000      60000           28-01-2023  13.432836   13.333333
#
#     Total Sales
# 0     3350000.0
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN

# %%
# 5. 	Plot top 5 sales for each Region

df = df.sort_values(by=['Region', 'Sales'], ascending=[True, False])

top_5_sales = df.groupby('Region').head(5)

plt.figure(figsize=(10, 6))
for region, data in top_5_sales.groupby('Region'):
    plt.bar(data['Name'], data['Sales'], label=region)

plt.xlabel('Name')
plt.ylabel('Sales')
plt.title('Top 5 Sales for Each Region')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# 6	Plot the chart -> percentage contribution of sales for Unique Name

name_sales = df.groupby('Name')['Sales'].sum().reset_index()

# %%
name_sales
# Out:
#                    Name   Sales
# 0  De Pasquale, Richard  300000
# 1      De Sousa, Kristi  800000
# 2        De Vries, John  350000
# 3       Defonso, Daniel  450000
# 4        Dillard, Susan  250000
# 5        Dobbert, Susan  400000
# 6         Dunton, Donna  600000
# 7                  John  200000

# %%
# Sales% through Python

total_sales = name_sales['Sales'].sum()
name_sales['Percentage'] = (name_sales['Sales'] / total_sales) * 100

# %%
name_sales['Percentage']
# Out:
# 0     8.955224
# 1    23.880597
# 2    10.447761
# 3    13.432836
# 4     7.462687
# 5    11.940299
# 6    17.910448
# 7     5.970149
# Name: Percentage, dtype: float64

# %%
name_sales
# Out:
#                    Name   Sales  Percentage
# 0  De Pasquale, Richard  300000    8.955224
# 1      De Sousa, Kristi  800000   23.880597
# 2        De Vries, John  350000   10.447761
# 3       Defonso, Daniel  450000   13.432836
# 4        Dillard, Susan  250000    7.462687
# 5        Dobbert, Susan  400000   11.940299
# 6         Dunton, Donna  600000   17.910448
# 7                  John  200000    5.970149
